# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(data)
# Out:
# (array([  5.,  24.,  84., 147., 255., 231., 150.,  83.,  19.,   2.]),
#  array([-3.12066314, -2.49832385, -1.87598455, -1.25364525, -0.63130596,
#         -0.00896666,  0.61337264,  1.23571193,  1.85805123,  2.48039052,
#          3.10272982]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure(figsize=(4.5,3))
ax = plt.axes()
ax.hist(data);

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(data, 
         bins = 50,
         alpha = 0.5,
         color = "steelblue"
         );

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha = 0.3, bins = 20)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.Figure()
ax = plt.axes()
limites = ax.hist(x1, alpha = 0.2, bins = 30)

# %%
limites[0] # conteo de cada barra
# Out:
# array([ 1.,  2.,  2.,  4.,  3., 14., 10., 15., 33., 35., 57., 62., 91.,
#        83., 79., 78., 76., 81., 77., 48., 44., 34., 28., 15., 12.,  4.,
#         8.,  2.,  0.,  2.])

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites[1] # intrervalos
# Out:
# array([-2.66841645, -2.49334326, -2.31827007, -2.14319687, -1.96812368,
#        -1.79305049, -1.61797729, -1.4429041 , -1.26783091, -1.09275771,
#        -0.91768452, -0.74261133, -0.56753813, -0.39246494, -0.21739175,
#        -0.04231855,  0.13275464,  0.30782783,  0.48290103,  0.65797422,
#         0.83304741,  1.00812061,  1.1831938 ,  1.35826699,  1.53334019,
#         1.70841338,  1.88348657,  2.05855976,  2.23363296,  2.40870615,
#         2.58377934])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt.boxplot(data, whis = 1.5)# define el coeficiente por el que se m7ultiplica el indice  o rango intercuartílico
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209dbd38080>,
#   <matplotlib.lines.Line2D at 0x209dbead520>],
#  'caps': [<matplotlib.lines.Line2D at 0x209dbeae540>,
#   <matplotlib.lines.Line2D at 0x209dbf6e870>],
#  'boxes': [<matplotlib.lines.Line2D at 0x209dbcc8d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x209dbf302f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209dbd54380>],
#  'means': []}

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(data, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209da83f500>,
#   <matplotlib.lines.Line2D at 0x209dba39a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x209dba39cd0>,
#   <matplotlib.lines.Line2D at 0x209dba3a1e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x209dbaf2030>],
#  'medians': [<matplotlib.lines.Line2D at 0x209dba3af60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209dba3aea0>],
#  'means': []}

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt.boxplot([x1,x2,x3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209dbc4ee70>,
#   <matplotlib.lines.Line2D at 0x209dbc4ef90>,
#   <matplotlib.lines.Line2D at 0x209dbc4d3a0>,
#   <matplotlib.lines.Line2D at 0x209dbc4d250>,
#   <matplotlib.lines.Line2D at 0x209dbc32330>,
#   <matplotlib.lines.Line2D at 0x209dbc31ca0>],
#  'caps': [<matplotlib.lines.Line2D at 0x209dbc4cda0>,
#   <matplotlib.lines.Line2D at 0x209dbc4d6d0>,
#   <matplotlib.lines.Line2D at 0x209dbc4cf20>,
#   <matplotlib.lines.Line2D at 0x209dbc4c0e0>,
#   <matplotlib.lines.Line2D at 0x209dbc30920>,
#   <matplotlib.lines.Line2D at 0x209dbc32960>],
#  'boxes': [<matplotlib.lines.Line2D at 0x209dbc4f7d0>,
#   <matplotlib.lines.Line2D at 0x209dbc4cc20>,
#   <matplotlib.lines.Line2D at 0x209dbc30ef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x209dbc4dbb0>,
#   <matplotlib.lines.Line2D at 0x209db8bdc70>,
#   <matplotlib.lines.Line2D at 0x209dbc31490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209dbc4dcd0>,
#   <matplotlib.lines.Line2D at 0x209dbc31fd0>,
#   <matplotlib.lines.Line2D at 0x209dbc312e0>],
#  'means': []}
