# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre el análisis bivariante, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos se subirá a lo largo del sprint.

# %% [markdown]
# ### Ejercicio 0
#
#
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from bootcampviztools import plot_categorical_relationship_fin, plot_categorical_numerical_relationship, plot_combined_graphs, \
    pinta_distribucion_categoricas, plot_grouped_boxplots, plot_combined_graphs, grafico_dispersion_con_correlacion

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Carga el dataset de admisiones que conoces de la unidad anterior y que se encuentra en la ruta "./data/admission_data.csv", deshazte de las columnas innecesarias

# %%
admisiones = pd.read_csv("./data/admission_data.csv")
admisiones.head()
# Out:
#    Unnamed: 0  Year                    Major Gender Admission
# 0           0  1973       School of Medicine      F  Rejected
# 1           1  1973  Department of Economics      M  Accepted
# 2           2  1973                    Other      F  Accepted
# 3           3  1973                    Other      M  Accepted
# 4           4  1973                    Other      M  Rejected

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Haz el análisis bivariante de "Admission" y "Major" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio) y contesta a las siguientes preguntas:
# * ¿Cuál es el departamento con el mayor porcentaje de admsiones?¿Y el de menor?
# * ¿Existe alguna diferencia destacada entre los departamentos?

# %%
pinta_distribucion_categoricas(admisiones,["Major","Admission"], relativa= True, mostrar_valores= True)

# %%
plot_categorical_relationship_fin(admisiones, "Major","Admission", show_values= True)

# %% [markdown]
# ### Ejercicio 3
#
# Repite el análisis para "Admission" y "Gender" y responde a las siguientes preguntas:
# * ¿Existe una diferencia visual significativa entre el porcentaje de admitidos de cada género?
# * ¿Cuál de los dos grupos tiene más admisiones?

# %%
pinta_distribucion_categoricas(admisiones,["Gender","Admission"], relativa= True, mostrar_valores= True)

# %%
plot_categorical_relationship_fin(admisiones, "Gender","Admission", show_values= True)

# %% [markdown]
# ### Ejercicio 4
#
# Carga el dataset de propinas (tips) que conoces de la unidad anterior y que se encuentra en la ruta "./data/tips.csv", deshazte de las columnas innecesarias

# %%
tips = pd.read_csv("./data/tips.csv")
tips.head()
tips = tips.drop(columns=["Unnamed: 0"])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Ejercicio 5
#
# Haz el análisis bivariante de "tip" y "sex" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio), añade el cálculo de la media y mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguientes preguntas:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "sex"?
# * ¿Son diferentes respecto al  conjunto total?

# %%
pinta_distribucion_categoricas(tips,["sex"], relativa= True, mostrar_valores= True)

# %%
plot_combined_graphs(tips,["tip"])
# Out:
# (2,)

# %%
plot_categorical_numerical_relationship(tips,"sex","tip", measure = "median")

# %%
plot_grouped_boxplots(tips,"sex","tip")

# %%
tips[tips["sex"] == "Male"].describe(include="all")
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   157.000000  157.000000   157    157  157     157  157.000000
# unique         NaN         NaN     1      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157     97   59     124         NaN
# mean     20.744076    3.089618   NaN    NaN  NaN     NaN    2.630573
# std       9.246469    1.489102   NaN    NaN  NaN     NaN    0.955997
# min       7.250000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      14.000000    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      18.350000    3.000000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.710000    3.760000   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips[tips["sex"] == "Female"].describe(include="all")
# Out:
#         total_bill        tip     sex smoker   day    time       size
# count    87.000000  87.000000      87     87    87      87  87.000000
# unique         NaN        NaN       1      2     4       2        NaN
# top            NaN        NaN  Female     No  Thur  Dinner        NaN
# freq           NaN        NaN      87     54    32      52        NaN
# mean     18.056897   2.833448     NaN    NaN   NaN     NaN   2.459770
# std       8.009209   1.159495     NaN    NaN   NaN     NaN   0.937644
# min       3.070000   1.000000     NaN    NaN   NaN     NaN   1.000000
# 25%      12.750000   2.000000     NaN    NaN   NaN     NaN   2.000000
# 50%      16.400000   2.750000     NaN    NaN   NaN     NaN   2.000000
# 75%      21.520000   3.500000     NaN    NaN   NaN     NaN   3.000000
# max      44.300000   6.500000     NaN    NaN   NaN     NaN   6.000000

# %% [markdown]
# ### Ejercicio 6
#
# Repite el análisis pero esta vez para "tip" y "smoker", añade también el cálculo de la media y de la mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguiente pregunta:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "smoker"?

# %%
pinta_distribucion_categoricas(tips,["smoker"], relativa= True, mostrar_valores= True)

# %%
plot_categorical_numerical_relationship(tips,"smoker","tip", measure = "median")

# %%
plot_grouped_boxplots(tips,"smoker","tip")

# %%
tips[tips["smoker"] == "Yes"].describe(include="all")
# Out:
#         total_bill        tip   sex smoker  day    time       size
# count    93.000000  93.000000    93     93   93      93  93.000000
# unique         NaN        NaN     2      1    4       2        NaN
# top            NaN        NaN  Male    Yes  Sat  Dinner        NaN
# freq           NaN        NaN    60     93   42      70        NaN
# mean     20.756344   3.008710   NaN    NaN  NaN     NaN   2.408602
# std       9.832154   1.401468   NaN    NaN  NaN     NaN   0.810751
# min       3.070000   1.000000   NaN    NaN  NaN     NaN   1.000000
# 25%      13.420000   2.000000   NaN    NaN  NaN     NaN   2.000000
# 50%      17.920000   3.000000   NaN    NaN  NaN     NaN   2.000000
# 75%      26.860000   3.680000   NaN    NaN  NaN     NaN   3.000000
# max      50.810000  10.000000   NaN    NaN  NaN     NaN   5.000000

# %%
tips[tips["smoker"] == "No"].describe(include="all")
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   151.000000  151.000000   151    151  151     151  151.000000
# unique         NaN         NaN     2      1    4       2         NaN
# top            NaN         NaN  Male     No  Sun  Dinner         NaN
# freq           NaN         NaN    97    151   57     106         NaN
# mean     19.188278    2.991854   NaN    NaN  NaN     NaN    2.668874
# std       8.255582    1.377190   NaN    NaN  NaN     NaN    1.017984
# min       7.250000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.325000    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.590000    2.740000   NaN    NaN  NaN     NaN    2.000000
# 75%      22.755000    3.505000   NaN    NaN  NaN     NaN    3.000000
# max      48.330000    9.000000   NaN    NaN  NaN     NaN    6.000000

# %% [markdown]
# ### Ejericicio 7
#
# Carga ahora el datase de accidentes de coches, que se encuentra en la ruta "./data/car_crashes.csv" y deshazte de las columnas innecesarias

# %%
accidentes = pd.read_csv("./data/car_crashes.csv", sep="|")
accidentes.head()
# Out:
#    Unnamed: 0  total  speeding  alcohol  not_distracted  no_previous  \
# 0           0   18.8     7.332    5.640          18.048       15.040
# 1           1   18.1     7.421    4.525          16.290       17.014
# 2           2   18.6     6.510    5.208          15.624       17.856
# 3           3   22.4     4.032    5.824          21.056       21.280
# 4           4   12.0     4.200    3.360          10.920       10.680
#
#    ins_premium  ins_losses abbrev
# 0       784.55      145.08     AL
# 1      1053.48      133.93     AK
# 2       899.47      110.35     AZ
# 3       827.34      142.39     AR
# 4       878.41      165.63     CA

# %%
accidentes = accidentes.drop(columns=["Unnamed: 0"])

# %% [markdown]
# ### Ejercicio 8
#
# Haz un analisis bivairante entre "total" y "speeding". Muestra su diagrama de dispersión y su valor de correlación de pearson obtenido con pandas. Luego contesta a la siguiente pregunta
# * ¿Existe alguna relación visual entre las variables?¿Y numérica?

# %%
plot_combined_graphs(accidentes,["total"])
# Out:
# (2,)

# %%
plot_combined_graphs(accidentes,["speeding"])
# Out:
# (2,)

# %%
accidentes[["speeding","total"]].describe()
# Out:
#         speeding      total
# count  51.000000  51.000000
# mean    4.998196  15.790196
# std     2.017747   4.122002
# min     1.792000   5.900000
# 25%     3.766500  12.750000
# 50%     4.608000  15.600000
# 75%     6.439000  18.500000
# max     9.450000  23.900000

# %% [markdown]
# ### Ejercicio 9
#
# Usa scipy tal como lo hicimos en el workout para hacer el test de correlación. ¿Cuál es el p-value?¿Qué podemos decir de la correlación lineal entre "total" y "speeding"?

# %%
accidentes[["speeding","total"]].corr()
# Out:
#           speeding     total
# speeding  1.000000  0.611548
# total     0.611548  1.000000

# %% [markdown]
# la correlación está más cerca de 1 que de 0 por lo que hay cierta correlación

# %%
from scipy.stats import pearsonr

pearsonr(accidentes["speeding"], accidentes["total"])
#da la correlacón y el p.value muy cercano a 0, lo que indica que la correlación es estadísticamente significativa.
# Out:
# PearsonRResult(statistic=np.float64(0.6115476008001186), pvalue=np.float64(1.8670391109056657e-06))

# %%
grafico_dispersion_con_correlacion(accidentes, "speeding", "total", 60)
