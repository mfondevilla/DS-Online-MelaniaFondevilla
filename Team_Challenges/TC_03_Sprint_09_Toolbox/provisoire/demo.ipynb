# %%
import sys
from pathlib import Path

# subir al directorio raíz del repo
sys.path.append(str(Path.cwd().parent))

from toolboxa_ml.eda.core import describe_df, tipifica_variables
import pandas as pd

df = pd.read_csv("data/titanic.csv")  
df.head()

# %%
describe_df(df)

# %%
tipifica = tipifica_variables(df, umbral_categorica=10, umbral_continua=0.5)
display(tipifica)
